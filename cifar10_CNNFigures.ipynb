# %%
import numpy as np
import matplotlib.pyplot as plt

seed = 1234
np.random.seed(seed)

# %%
finalModel = np.array([[1,    10, 2.254], [1,    20,2.058],[1,    30, 1.972],[1,    40, 1.874],[2,    10, 1.799],[2,    20, 1.677],
[2,    30, 1.611], [2,    40, 1.520],[3,    10, 1.574],[3,    20, 1.463],[3,    30, 1.398],[3,    40, 1.317],[4,    10, 1.342],
[4,    20, 1.281], [4,    30, 1.217],[4,    40, 1.212],[5,    10, 1.179],[5,    20, 1.128],[5,    30, 1.115],[5,    40, 1.093],
[6,    10, 1.091],[6,    20, 1.018],[6,    30, 1.010],[6,    40, 0.958],[7,    10, 0.922],[7,    20, 0.883],[7,    30, 0.875],
[7,    40, 0.853],[8,    10, 0.848],[8,    20, 0.815],[8,    30, 0.762],[8,    40, 0.748],[9,    10, 0.755],[9,    20, 0.710],
[9,    30, 0.698],[9,    40,0.656],[10,    10, 0.618],[10,    20, 0.607],[10,    30, 0.598],[10,    40, 0.604],[11,    10, 0.581],
[11,    20, 0.554],[11,    30, 0.558],[11,    40, 0.554],[12,    10, 0.600],[12,    20, 0.492],[12,    30, 0.466],[12,    40, 0.437],
[13,    10, 0.398],[13,    20, 0.393],[13,    30, 0.365],[13,    40, 0.355],[14,    10, 0.327],[14,    20, 0.288],[14,    30, 0.298],
[14,    40, 0.272],[15,    10, 0.241],[15,    20, 0.208],[15,    30, 0.196],[15,    40, 0.187],[16,    10, 0.195],[16,    20, 0.156],
[16,    30, 0.149],[16,    40, 0.168],[17,    10, 0.134],[17,    20, 0.106],[17,    30, 0.092],[17,    40, 0.088],[18,    10, 0.082],
[18,    20, 0.060],[18,    30, 0.052],[18,    40,0.063],[19,    10, 0.061],[19,    20, 0.047],[19,    30, 0.038],[19,    40,0.038],
[20,    10, 0.044],[20,    20,0.036],[20,    30,0.036],[20,    40, 0.030],[21,    10, 0.021],[21,    20, 0.021],[21,    30,0.017],
[21,    40, 0.018],[22,    10,0.078],[22,    20, 0.158],[22,    30, 0.103],[22,    40, 0.066],[23,    10, 0.067],[23,    20, 0.044],
[23,    30, 0.037],[23,    40, 0.024],[24,    10, 0.029],[24,    20, 0.025],[24,    30, 0.016],[24,    40, 0.016],[25,    10, 0.023],
[25,    20, 0.023],[25,    30, 0.015],[25,    40, 0.014],[26,    10, 0.010],[26,    20, 0.009],[26,    30, 0.006],[26,    40, 0.006],
[27,    10, 0.003],[27,    20, 0.002],[27,    30,0.001],[27,    40, 0.002],[28,    10, 0.001],[28,    20,0.001],[28,    30, 0.001],
[28,    40, 0.001],[29,    10, 0.001],[29,    20, 0.000],[29,    30, 0.000],[29,    40, 0.000],[30,    10, 0.000],[30,    20,0.000],
[30,    30,0.000],[30,    40,0.000],[31,    10,0.000],[31,    20,0.000],[31,    30,0.000],[31,    40,0.000],[32,    10, 0.000],
[32,    20, 0.000],[32,    30, 0.000],[32,    40, 0.000],[33,    10, 0.000],[33,    20, 0.000],[33,    30, 0.000],[33,    40,0.000],
[34,    10, 0.000],[34,    20, 0.000],[34,    30, 0.000],[34,    40, 0.000],[35,    10, 0.000],[35,    20, 0.000],[35,    30, 0.000],
[35,    40,0.000],[36,    10, 0.000],[36,    20, 0.000],[36,    30,0.000],[36,    40,0.000],[37,    10,0.000],[37,    20,0.000],
[37,    30,0.000],[37,    40,0.000],[38,    10,0.000],[38,    20, 0.000],[38,    30,0.000],[38,    40,0.000],[39,    10,0.000],
[39,    20,0.000],[39,    30,0.000],[39,    40,0.000],[40,    10,0.000],[40,    20,0.000],[40,    30, 0.000],[40,    40,0.000]])

# %%
figure, axes = plt.subplots()

epochs = finalModel[:,0]


axes.plot(epochs, finalModel[:,2])

axes.set_xticks([0, 10, 20, 30, 40])

#axes.set_title("", size=16)

axes.set_xlabel("Epochs", size=11)
axes.set_ylabel("Loss", size=11)

axes.legend(["lr=0.001, batch_size=1024, 4 conv layers"], loc=1)

plt.show()
